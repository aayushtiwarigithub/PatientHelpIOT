# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import random
from random import shuffle

import keras
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler , LabelEncoder
from keras.models import Model, Sequential
from keras.layers import Dense, Activation, Flatten, BatchNormalization, Conv2D, MaxPooling2D, Dropout
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
df = pd.read_csv("C:\\Users\\atiwa117\\Downloads\\heart.csv")

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
df = df[['age', 'sex', 'trestbps', 'chol','fbs','restecg', 'thalach','target']]

# %%
df = np.take(df,np.random.permutation(df.shape[0]),axis=0);

# %%
df.head()
# Out:
#      age  sex  trestbps  chol  fbs  restecg  thalach  target
# 267   49    1       118   149    0        0      126       0
# 112   64    0       140   313    0        1      133       1
# 48    53    0       128   216    0        0      115       1
# 29    53    1       130   197    1        0      152       1
# 4     57    0       120   354    0        1      163       1

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df.corr(),annot=True,cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
x = df.iloc[:,:7].values
y = df.iloc[:,7].values

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.25,random_state = 0)

# %%
# sc = StandardScaler()
# x_train = sc.fit_transform(x_train)
# x_test = sc.fit_transform(x_test)

# %%
model = Sequential()

model.add(Dense(6))
model.add(Activation('relu'))

model.add(Dense(8))
model.add(Activation('relu'))

model.add(Flatten())

model.add(Dense(1))
model.add(Activation('sigmoid'))

model.compile(loss = 'binary_crossentropy',optimizer = 'adam',metrics = ['accuracy'])
print('<< Compiling Model >>')

history_1 = model.fit(x_train,y_train ,batch_size = 32 ,epochs = 200)

plt.plot(history_1.history['accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train'], loc='upper left')
plt.show()

y_pred_1 = model.predict(x_test)
y_pred_1 = (y_pred_1 > 0.5)
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred_1)
print(cm)
print(accuracy_score(y_test, y_pred_1))

pred_1 = 100*accuracy_score(y_test,y_pred_1)
print('percentage Accuracy : ',pred_1)
# Out:
# << Compiling Model >>
# Epoch 1/200
# 8/8 [==============================] - 0s 1ms/step - loss: 34.5131 - accuracy: 0.4405
# Epoch 2/200
# 8/8 [==============================] - 0s 1ms/step - loss: 30.3419 - accuracy: 0.4405
# Epoch 3/200
# 8/8 [==============================] - 0s 1ms/step - loss: 26.4390 - accuracy: 0.4405
# Epoch 4/200
# 8/8 [==============================] - 0s 1ms/step - loss: 22.6079 - accuracy: 0.4405
# Epoch 5/200
# 8/8 [==============================] - 0s 1ms/step - loss: 19.0586 - accuracy: 0.4405
# Epoch 6/200
# 8/8 [==============================] - 0s 1ms/step - loss: 15.7624 - accuracy: 0.4405
# Epoch 7/200
# 8/8 [==============================] - 0s 1ms/step - loss: 12.8264 - accuracy: 0.4405
# Epoch 8/200
# 8/8 [==============================] - 0s 1ms/step - loss: 9.8585 - accuracy: 0.4405
# Epoch 9/200
# 8/8 [==============================] - 0s 1ms/step - loss: 7.1070 - accuracy: 0.4405
# Epoch 10/200
# 8/8 [==============================] - 0s 1ms/step - loss: 4.5674 - accuracy: 0.4405
# Epoch 11/200
# 8/8 [==============================] - 0s 1ms/step - loss: 2.1055 - accuracy: 0.4405
# Epoch 12/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.7468 - accuracy: 0.5330
# Epoch 13/200
# 8/8 [==============================] - 0s 1ms/step - loss: 1.0279 - accuracy: 0.5595
# Epoch 14/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.8341 - accuracy: 0.5595
# Epoch 15/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6945 - accuracy: 0.4934
# Epoch 16/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.7797 - accuracy: 0.4361
# Epoch 17/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7149 - accuracy: 0.4714
# Epoch 18/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6933 - accuracy: 0.5595
# Epoch 19/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6935 - accuracy: 0.5595
# Epoch 20/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6866 - accuracy: 0.5595
# Epoch 21/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7003 - accuracy: 0.4758
# Epoch 22/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6858 - accuracy: 0.5595
# Epoch 23/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6965 - accuracy: 0.5595
# Epoch 24/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6864 - accuracy: 0.5595
# Epoch 25/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6977 - accuracy: 0.5154
# Epoch 26/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6909 - accuracy: 0.5507
# Epoch 27/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6906 - accuracy: 0.5595
# Epoch 28/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6912 - accuracy: 0.5595
# Epoch 29/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6894 - accuracy: 0.5595
# Epoch 30/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6876 - accuracy: 0.5595
# Epoch 31/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6898 - accuracy: 0.5595
# Epoch 32/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6887 - accuracy: 0.5595
# Epoch 33/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6869 - accuracy: 0.5595
# Epoch 34/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6876 - accuracy: 0.5595
# Epoch 35/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6973 - accuracy: 0.5595
# Epoch 36/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6935 - accuracy: 0.5595
# Epoch 37/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6876 - accuracy: 0.5595
# Epoch 38/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6882 - accuracy: 0.5595
# Epoch 39/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6950 - accuracy: 0.5595
# Epoch 40/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6944 - accuracy: 0.5198
# Epoch 41/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6996 - accuracy: 0.4934
# Epoch 42/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7007 - accuracy: 0.5595
# Epoch 43/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6926 - accuracy: 0.5595
# Epoch 44/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6883 - accuracy: 0.5595
# Epoch 45/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6897 - accuracy: 0.5595
# Epoch 46/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6994 - accuracy: 0.5595
# Epoch 47/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6953 - accuracy: 0.5595
# Epoch 48/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6909 - accuracy: 0.5198
# Epoch 49/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6918 - accuracy: 0.5595
# Epoch 50/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6909 - accuracy: 0.5595
# Epoch 51/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6868 - accuracy: 0.5595
# Epoch 52/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6893 - accuracy: 0.5595
# Epoch 53/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6972 - accuracy: 0.5507
# Epoch 54/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6976 - accuracy: 0.5551
# Epoch 55/200
# 8/8 [==============================] - 0s 1000us/step - loss: 0.6891 - accuracy: 0.5595
# Epoch 56/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6949 - accuracy: 0.4978
# Epoch 57/200
# 8/8 [==============================] - 0s 1000us/step - loss: 0.6909 - accuracy: 0.5507
# Epoch 58/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6911 - accuracy: 0.5595
# Epoch 59/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6965 - accuracy: 0.4978
# Epoch 60/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6893 - accuracy: 0.5551
# Epoch 61/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6898 - accuracy: 0.5595
# Epoch 62/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7030 - accuracy: 0.5595
# Epoch 63/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6863 - accuracy: 0.5595
# Epoch 64/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.7015 - accuracy: 0.4273
# Epoch 65/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6903 - accuracy: 0.5551
# Epoch 66/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6925 - accuracy: 0.5551
# Epoch 67/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6997 - accuracy: 0.4626
# Epoch 68/200
# 8/8 [==============================] - 0s 1000us/step - loss: 0.6990 - accuracy: 0.5595
# Epoch 69/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6948 - accuracy: 0.5595
# Epoch 70/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6904 - accuracy: 0.5595
# Epoch 71/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6894 - accuracy: 0.5551
# Epoch 72/200
# 8/8 [==============================] - 0s 1000us/step - loss: 0.6902 - accuracy: 0.5595
# Epoch 73/200
# 8/8 [==============================] - 0s 974us/step - loss: 0.6908 - accuracy: 0.5595
# Epoch 74/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.7036 - accuracy: 0.4802
# Epoch 75/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6951 - accuracy: 0.4978
# Epoch 76/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6975 - accuracy: 0.5595
# Epoch 77/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6866 - accuracy: 0.5595
# Epoch 78/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6959 - accuracy: 0.5066
# Epoch 79/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6872 - accuracy: 0.5595
# Epoch 80/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6853 - accuracy: 0.5595
# Epoch 81/200
# 8/8 [==============================] - 0s 1000us/step - loss: 0.6898 - accuracy: 0.5595
# Epoch 82/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6870 - accuracy: 0.5595
# Epoch 83/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6815 - accuracy: 0.5595
# Epoch 84/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.7064 - accuracy: 0.5595
# Epoch 85/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6893 - accuracy: 0.5595
# Epoch 86/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6897 - accuracy: 0.5595
# Epoch 87/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6836 - accuracy: 0.5595
# Epoch 88/200
# 8/8 [==============================] - 0s 999us/step - loss: 0.6890 - accuracy: 0.5595
# Epoch 89/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.7002 - accuracy: 0.4670
# Epoch 90/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6889 - accuracy: 0.5374
# Epoch 91/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6888 - accuracy: 0.5595
# Epoch 92/200
# 8/8 [==============================] - 0s 1000us/step - loss: 0.6850 - accuracy: 0.5595
# Epoch 93/200
# 8/8 [==============================] - 0s 1000us/step - loss: 0.6861 - accuracy: 0.5595
# Epoch 94/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6857 - accuracy: 0.5595
# Epoch 95/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.7003 - accuracy: 0.4405
# Epoch 96/200
# 8/8 [==============================] - 0s 1000us/step - loss: 0.7109 - accuracy: 0.5595
# Epoch 97/200
# 8/8 [==============================] - 0s 1000us/step - loss: 0.6974 - accuracy: 0.5595
# Epoch 98/200
# 8/8 [==============================] - 0s 1000us/step - loss: 0.6908 - accuracy: 0.5595
# Epoch 99/200
# 8/8 [==============================] - 0s 1000us/step - loss: 0.6992 - accuracy: 0.5595
# Epoch 100/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6959 - accuracy: 0.4361
# Epoch 101/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6996 - accuracy: 0.4317
# Epoch 102/200
# 8/8 [==============================] - 0s 1000us/step - loss: 0.6841 - accuracy: 0.5595
# Epoch 103/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6834 - accuracy: 0.5595
# Epoch 104/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.7031 - accuracy: 0.4053
# Epoch 105/200
# 8/8 [==============================] - 0s 1000us/step - loss: 0.6939 - accuracy: 0.5595
# Epoch 106/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6907 - accuracy: 0.5595
# Epoch 107/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.7714 - accuracy: 0.4141
# Epoch 108/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6762 - accuracy: 0.5595
# Epoch 109/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.7112 - accuracy: 0.5595
# Epoch 110/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6855 - accuracy: 0.5595
# Epoch 111/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6928 - accuracy: 0.5507
# Epoch 112/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6854 - accuracy: 0.5595
# Epoch 113/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6858 - accuracy: 0.5595
# Epoch 114/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6885 - accuracy: 0.5595
# Epoch 115/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6851 - accuracy: 0.5595
# Epoch 116/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7004 - accuracy: 0.4493
# Epoch 117/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6913 - accuracy: 0.5595
# Epoch 118/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6950 - accuracy: 0.5595
# Epoch 119/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6908 - accuracy: 0.5595
# Epoch 120/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6869 - accuracy: 0.5595
# Epoch 121/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6906 - accuracy: 0.5595
# Epoch 122/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6832 - accuracy: 0.5595
# Epoch 123/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6944 - accuracy: 0.4714
# Epoch 124/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6861 - accuracy: 0.5595
# Epoch 125/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6853 - accuracy: 0.5595
# Epoch 126/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7116 - accuracy: 0.4185
# Epoch 127/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6889 - accuracy: 0.5507
# Epoch 128/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7132 - accuracy: 0.5595
# Epoch 129/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6833 - accuracy: 0.5595
# Epoch 130/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6932 - accuracy: 0.5595
# Epoch 131/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6878 - accuracy: 0.5595
# Epoch 132/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6851 - accuracy: 0.5595
# Epoch 133/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6840 - accuracy: 0.5595
# Epoch 134/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6882 - accuracy: 0.5595
# Epoch 135/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6856 - accuracy: 0.5595
# Epoch 136/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6853 - accuracy: 0.5595
# Epoch 137/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6971 - accuracy: 0.4317
# Epoch 138/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6923 - accuracy: 0.4934
# Epoch 139/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7158 - accuracy: 0.5595
# Epoch 140/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6908 - accuracy: 0.5595
# Epoch 141/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6872 - accuracy: 0.5595
# Epoch 142/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6916 - accuracy: 0.4714
# Epoch 143/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6835 - accuracy: 0.5595
# Epoch 144/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6967 - accuracy: 0.5595
# Epoch 145/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6808 - accuracy: 0.5595
# Epoch 146/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6832 - accuracy: 0.5595
# Epoch 147/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6831 - accuracy: 0.5595
# Epoch 148/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6980 - accuracy: 0.4934
# Epoch 149/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6938 - accuracy: 0.5595
# Epoch 150/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6938 - accuracy: 0.5595
# Epoch 151/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6913 - accuracy: 0.4626
# Epoch 152/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6816 - accuracy: 0.5595
# Epoch 153/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6843 - accuracy: 0.5595
# Epoch 154/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6881 - accuracy: 0.5595
# Epoch 155/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6850 - accuracy: 0.5595
# Epoch 156/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6880 - accuracy: 0.5595
# Epoch 157/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6908 - accuracy: 0.5507
# Epoch 158/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6827 - accuracy: 0.5595
# Epoch 159/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6897 - accuracy: 0.5595
# Epoch 160/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6847 - accuracy: 0.5595
# Epoch 161/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6829 - accuracy: 0.5595
# Epoch 162/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6957 - accuracy: 0.5595
# Epoch 163/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6890 - accuracy: 0.4846
# Epoch 164/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6961 - accuracy: 0.4714
# Epoch 165/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7059 - accuracy: 0.5595
# Epoch 166/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.7010 - accuracy: 0.4934
# Epoch 167/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6831 - accuracy: 0.5507
# Epoch 168/200
# 8/8 [==============================] - 0s 6ms/step - loss: 0.7340 - accuracy: 0.5595
# Epoch 169/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.8108 - accuracy: 0.4493
# Epoch 170/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7126 - accuracy: 0.5551
# Epoch 171/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7523 - accuracy: 0.5595
# Epoch 172/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7533 - accuracy: 0.4405
# Epoch 173/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6829 - accuracy: 0.5463
# Epoch 174/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7032 - accuracy: 0.5595
# Epoch 175/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6851 - accuracy: 0.5595
# Epoch 176/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6826 - accuracy: 0.5595
# Epoch 177/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6855 - accuracy: 0.5595
# Epoch 178/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6839 - accuracy: 0.5595
# Epoch 179/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6848 - accuracy: 0.5595
# Epoch 180/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6815 - accuracy: 0.5595
# Epoch 181/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6927 - accuracy: 0.5595
# Epoch 182/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6931 - accuracy: 0.5595
# Epoch 183/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6840 - accuracy: 0.5595
# Epoch 184/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6962 - accuracy: 0.5595
# Epoch 185/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6933 - accuracy: 0.5595
# Epoch 186/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6847 - accuracy: 0.5595
# Epoch 187/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7063 - accuracy: 0.5595
# Epoch 188/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6873 - accuracy: 0.5595
# Epoch 189/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6865 - accuracy: 0.5595
# Epoch 190/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6985 - accuracy: 0.4537
# Epoch 191/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6806 - accuracy: 0.5595
# Epoch 192/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6801 - accuracy: 0.5595
# Epoch 193/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6828 - accuracy: 0.5595
# Epoch 194/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6812 - accuracy: 0.5595
# Epoch 195/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6914 - accuracy: 0.5595
# Epoch 196/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7015 - accuracy: 0.4626
# Epoch 197/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7007 - accuracy: 0.5595
# Epoch 198/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6996 - accuracy: 0.5066
# Epoch 199/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6889 - accuracy: 0.5110
# Epoch 200/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6837 - accuracy: 0.5595
# 3/3 [==============================] - 0s 2ms/step
# [[ 0 38]
#  [ 0 38]]
# 0.5
# percentage Accuracy :  50.0

# %%
lr = LogisticRegression()
history_2 = lr.fit(x_train,y_train) 


y_pred_2 = lr.predict(x_test)
y_pred_2 = (y_pred_2 > 0.5)

from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred_2)
print(cm)
print(accuracy_score(y_test, y_pred_2))


pred_2 = 100*accuracy_score(y_test,y_pred_2)

print('percentage Accuracy : ',pred_2)
# Out:
# [[27 11]
#  [ 7 31]]
# 0.7631578947368421
# percentage Accuracy :  76.31578947368422
# C:\ProgramData\Anaconda3\envs\nlp\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
rnf = RandomForestClassifier(n_estimators=100,random_state=0,max_depth=5)
history_3 = rnf.fit(x_train,y_train)


y_pred_3 = rnf.predict(x_test)
y_pred_3 = (y_pred_3 > 0.5)

from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred_3)
print(cm)
print(accuracy_score(y_test, y_pred_3))

pred_3 = 100*accuracy_score(y_test,y_pred_3)

print('percentage Accuracy : ',pred_3)
# Out:
# [[25 13]
#  [ 6 32]]
# 0.75
# percentage Accuracy :  75.0

# %%
dt = DecisionTreeClassifier()
history_4 = dt.fit(x_train, y_train)


y_pred_4 = dt.predict(x_test)
y_pred_4 = (y_pred_4 > 0.5)

from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred_4)
print(cm)
print(accuracy_score(y_test, y_pred_4))

pred_4 = 100*accuracy_score(y_test,y_pred_4)

print('percentage Accuracy : ',pred_4)
# Out:
# [[26 12]
#  [10 28]]
# 0.7105263157894737
# percentage Accuracy :  71.05263157894737

# %%
height = [pred_1,pred_2,pred_3,pred_4]
bars = ('ANN','Logistic Reg.','Random Forest',' Decision Tree')
y_pos = np.arange(len(bars))

plt.bar(y_pos, height, color=['green', 'blue', 'cyan','red'])
plt.xticks(y_pos, bars)
plt.show()
